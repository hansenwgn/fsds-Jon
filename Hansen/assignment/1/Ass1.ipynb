# %%
import os
import numpy as np
import pandas as pd

# %%
# check the data
df = pd.read_csv('2020-08-24-listings.csv.gz', compression='gzip', low_memory=False)
print(f"Data frame is {df.shape[0]:,} x {df.shape[1]}")
# Out:
# Data frame is 74,188 x 74

# %%
pd.set_option('display.max_columns', None)
df.head(4)
# Out:
#         id                         listing_url       scrape_id last_scraped  \
# 0  11551.0  https://www.airbnb.com/rooms/11551  20200824024753   2020-08-26
# 1  13913.0  https://www.airbnb.com/rooms/13913  20200824024753   2020-08-27
# 2  15400.0  https://www.airbnb.com/rooms/15400  20200824024753   2020-08-26
# 3  17402.0  https://www.airbnb.com/rooms/17402  20200824024753   2020-08-27
#
#                                          name  \
# 0  Arty and Bright London Apartment in Zone 2
# 1         Holiday London DB Room Let-on going
# 2         Bright Chelsea  Apartment. Chelsea!
# 3       Superb 3-Bed/2 Bath & Wifi: Trendy W1
#
#                                          description  \
# 0  Unlike most rental apartments out there my fla...
# 1  My bright double bedroom with a large window h...
# 2  Lots of windows and light.  St Luke's Gardens ...
# 3  You'll have a wonderful stay in this superb mo...
#
#                                neighborhood_overview  \
# ...

# %%
df.describe(percentiles=[.05, .95]) # 0.5 is always shown
# Out:
#                  id       host_id  host_listings_count  \
# count  7.418600e+04  7.418800e+04         74175.000000
# mean   2.524026e+07  9.403591e+07            22.460775
# std    1.292372e+07  9.804038e+07           115.784574
# min    1.155100e+04  1.000000e+00             0.000000
# 5%     3.302336e+06  1.992189e+06             0.000000
# 50%    2.576235e+07  4.911094e+07             1.000000
# 95%    4.345711e+07  3.030589e+08            62.000000
# max    4.509040e+07  3.639824e+08          1309.000000
#
#        neighbourhood_group_cleansed      latitude     longitude  accommodates  \
# count                      2.000000  74186.000000  74186.000000  74186.000000
# mean                     570.000000     51.508588     -0.128352      3.129755
# std                      784.888527      0.261351      0.095638      1.989834
# min                       15.000000      2.000000     -0.496250      1.000000
# ...

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74188 entries, 0 to 74187
# Data columns (total 74 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            74186 non-null  float64
#  1   listing_url                                   74187 non-null  object
#  2   scrape_id                                     74187 non-null  object
#  3   last_scraped                                  74187 non-null  object
#  4   name                                          74167 non-null  object
#  5   description                                   71329 non-null  object
#  6   neighborhood_overview                         47208 non-null  object
#  7   picture_url                                   74188 non-null  object
#  8   host_id                                       74188 non-null  float64
# ...
